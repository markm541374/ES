# %%
import scipy as sp
from matplotlib import pyplot as plt
import scipy.stats as sps
import scipy.linalg as spl
# %matplotlib inline

import GPep
reload(GPep)
import GPd
reload(GPd)
import EntropyPredict
reload(EntropyPredict)
# Out:
# <module 'EntropyPredict' from 'EntropyPredict.pyc'>

# %%
kf = GPep.gen_sqexp_k_d([1.,0.5])

Xo=sp.matrix([[-0.85],[-0.7],[0.1],[0.4]])
Yo=sp.matrix([[0.35],[0.2],[-0.4],[-0.1]])
So=sp.matrix([[0.01],[0.01],[0.01],[0.01]])
Do=[[sp.NaN],[sp.NaN],[sp.NaN],[sp.NaN]]
g1=GPd.GPcore(Xo,Yo,So,Do,kf)
a=GPd.plot1(g1,[-1],[1])

# %%
Xi=sp.linspace(-1,1,701)
Si=[0.01]
H=EntropyPredict.predict_1dfixk([Xo,Yo,So,Do],kf,Xi,Si,nd=100)
EI=EntropyPredict.EI_1dfixk([Xo,Yo,So,Do],kf,Xi,-0.4)
# Out:
# 0
# 25
# 50
# 75

# %%
a=GPd.plot1(g1,[-1],[1])
a.plot(Xi,H[:,0],'r')
a.plot(Xi,3*EI,'g')
